# %%
import csv
import os
import parselmouth
import textgrids

# %%
vowels = "aeiou"
kmeans_theorethical_centers = {
    "a": [ 745.95822783, 1372.97015201, 70.34459972],
    "e": [ 513.45922943, 1660.80486614, 72.53580052],
    "i": [ 520.34845078, 2102.12912086, 73.54341813],
    "o": [ 478.93688623,  893.2153884,  71.62626969],
    "u": [ 472.41973725, 1251.09102164, 70.69878794]
}


DISTANCE_THRESHOLD = 100
def extract_f1_f2_and_intensity_from_sound(snd):
    formants = snd.to_formant_burg()
    intensity = snd.to_intensity()
    f1 = list()
    f2 = list()
    intensity_list = list()
    for t in formants.t_grid():
        f1.append(formants.get_value_at_time(1,t))
        f2.append(formants.get_value_at_time(2,t))
        intensity_list.append(intensity.get_value(t))

    return f1, f2, intensity_list, formants.t_grid()

def get_closer_vowel(f1,f2, theoretical_formants=kmeans_theorethical_centers):
    return min(
        map(
            lambda x:
                (x[0], abs(x[1] - f1) + abs(x[2] - f2)),
            ((vowel, t_f1, t_f2) for vowel, (t_f1, t_f2, i) in theoretical_formants.items())
        ),
        key=lambda x: x[1]
    )

def evaluate_non_vocal(vowel_and_distance, distance_threshold=DISTANCE_THRESHOLD):
    vowel, distance = vowel_and_distance
    if distance > distance_threshold:
        return (f'non_vocal_{vowel}', distance)
    return vowel_and_distance

# %%
base_folder = "words_annotations"
annotations_folder = "annotations"
wav_folder = "wav"
annotations_file_path = os.path.join(base_folder, "word_map.txt")
with open(annotations_file_path) as af:
    annotations = af.readlines()
annotations
# Out:
# ['27356,Arete\n',
#  '27358,Reloj\n',
#  '27361,Cadena\n',
#  '27364,Gafas\n',
#  '27365,Anillo\n',
#  '27387,Pollo\n',
#  '36677,Papa\n',
#  '32540,Yuca\n',
#  '33582,Tomate\n',
#  '31873,Zanahoria\n',
#  '36438,Cebolla\n',
#  '35472,Cilantro\n',
#  '29029,Pepino\n',
#  '32621,Habichuela\n',
#  '36271,Te amo\n',
#  '36358,Me gusta\n',
#  '31500,Quiero\n',
#  '35159,Feliz\n',
#  '34100,Triste\n',
#  '28102,Miedo\n',
#  '28728,Odio\n',
#  '32467,Culpa\n',
#  '33981,Enojo\n',
#  '35165,Aburrido\n',
#  '35616,Celos\n',
#  '36265,Amor\n',
#  '34617,Agua\n',
#  '33307,Café\n',
#  '27436,Jugo\n',
#  '29420,Leche\n',
#  '31317,Avena\n',
#  '34014,Chocolate\n',
#  '29809,Limonada\n',
#  '30373,Bombero\n',
#  '32784,Medico\n',
#  '30538,Profesor\n',
#  '28699,Estudiante\n',
#  '32438,Interpretador\n',
#  '28066,Conductor\n',
#  '36798,Enfermero\n',
#  '30380,Cantante\n',
#  '32791,Carpintero\n',
#  '29617,Chef\n',
#  '33954,Fotógrafo\n',
#  '31077,Músico\n',
#  '28487,Odontólogo\n',
#  '31485,Peluquero\n',
#  '36245,Periodista\n',
#  '33962,Piloto\n',
#  '36249,Policía\n',
#  '28492,Pintor\n',
#  '29182,Familia\n',
#  '28186,Papá\n',
#  '33026,Mamá\n',
#  '34274,Hermano\n',
#  '27893,Hermana\n',
#  '30737,Tío\n',
#  '34527,Tía\n',
#  '34040,Primo\n',
#  '33032,Prima\n',
#  '33130,Abuelo\n',
#  '27899,Abuela\n',
#  '34652,Hijo\n',
#  '34283,Hija\n',
#  '32572,Amigo\n',
#  '29455,Amiga\n',
#  '33039,Novio\n',
#  '29843,Novia\n',
#  '27640,Esposo\n',
#  '32316,Esposa\n',
#  '32837,Nieto\n',
#  '27944,Nieta\n',
#  '31014,Sobrino\n',
#  '34663,Sobrina\n',
#  '34056,Grupo\n',
#  '31650,Persona\n',
#  '35547,Niño\n',
#  '35483,Lápiz\n',
#  '31180,Lapicero\n',
#  '28786,Borrador\n',
#  '30453,Sacapunta\n',
#  '30660,Marcador\n',
#  '33568,Regla\n',
#  '28568,Cuaderno\n',
#  '28364,Maletín\n',
#  '34004,Futbol\n',
#  '27885,Baloncesto\n',
#  '33327,Atletismo\n',
#  '28180,Voleibol\n',
#  '29984,Natación\n',
#  '32689,Colegio\n',
#  '32878,Cine\n',
#  '32879,Hotel\n',
#  '33671,Parque\n',
#  '35870,Aeropuerto\n',
#  '32967,Panadería\n',
#  '31397,Banco\n',
#  '35725,Restaurante\n',
#  '32360,Museo\n',
#  '34335,Biblioteca\n',
#  '32972,Estadio\n',
#  '36156,Zoológico\n',
#  '27694,Gimnasio\n',
#  '35879,Hospital\n',
#  '29956,Universidad\n',
#  '30802,Iglesia\n',
#  '29958,Supermercado\n',
#  '29541,Droguería\n',
#  '32895,Casa\n',
#  '29543,Trabajo\n',
#  '32372,Piscina\n',
#  '30808,Baño\n',
#  '31051,Cuarto\n',
#  '36168,Sala\n',
#  '29905,Cocina\n',
#  '28113,Ojo\n',
#  '30670,Nariz\n',
#  '29346,Boca\n',
#  '29766,Oreja\n',
#  '28020,Cabello\n',
#  '29264,Manos\n',
#  '33271,Brazos\n',
#  '29351,Piernas\n',
#  '34585,Pies\n',
#  '30082,Cabeza\n',
#  '31222,Tronco\n',
#  '35049,Cero\n',
#  '30886,Uno\n',
#  '33764,Dos\n',
#  '30888,Tres\n',
#  '30512,Cuatro\n',
#  '28043,Cinco\n',
#  '28459,Seis\n',
#  '30515,Siete\n',
#  '29592,Ocho\n',
#  '35315,Nueve\n',
#  '31753,Diez\n',
#  '34972,Triangulo\n',
#  '27947,Cuadrado\n',
#  '34551,Circulo\n',
#  '27665,Rectángulo\n',
#  '32338,Línea\n',
#  '34897,Hamburguesa\n',
#  '29729,Perro Caliente\n',
#  '28248,Pizza\n',
#  '31888,Pandebono\n',
#  '31997,Pan\n',
#  '29754,Arroz\n',
#  '30065,Huevos\n',
#  '31892,Carne\n',
#  '33259,Pollo\n',
#  '33352,Pescado\n',
#  '33703,Salchichas\n',
#  '29760,Arepa\n',
#  '33054,Ensalada\n',
#  '33264,Pastel\n',
#  '35454,Manzana\n',
#  '31379,Pera\n',
#  '31669,Mango\n',
#  '34316,Sandia\n',
#  '28606,Naranja\n',
#  '31672,Uva\n',
#  '33661,Piña\n',
#  '27507,Mora\n',
#  '34690,Guanábana\n',
#  '28390,Banano\n',
#  '34692,Fresa\n',
#  '27966,Lulo\n',
#  '31679,Limón\n',
#  '33212,Alto\n',
#  '36101,Bajo\n',
#  '35274,Gordo\n',
#  '28844,Flaco\n',
#  '30162,Mucho\n',
#  '34356,Poco\n',
#  '31598,Arriba\n',
#  '29913,Abajo\n',
#  '31717,Cerca\n',
#  '29915,Lejos\n',
#  '31894,Encima\n',
#  '36181,Debajo\n',
#  '33224,Izquierda\n',
#  '30864,Derecha\n',
#  '32740,Adelante\n',
#  '30173,Atrás\n',
#  '36905,Grande\n',
#  '30868,Mediano\n',
#  '35290,Pequeño\n',
#  '34370,Largo\n',
#  '31436,Corto\n',
#  '32936,Dentro\n',
#  '34742,Fuera\n',
#  '36912,Bonito\n',
#  '35039,Feo\n',
#  '28028,Rápido\n',
#  '28867,Lento\n',
#  '34747,Blando\n',
#  '32754,Duro\n',
#  '36129,Sentarse\n',
#  '31739,Pararse\n',
#  '31740,Mayor\n',
#  '28873,Menor\n',
#  '32410,Igual\n',
#  '32587,Cumpleaños\n',
#  '33641,Navidad\n',
#  '31654,Año nuevo\n',
#  '27488,Día del Niño\n',
#  '28235,Halloween\n',
#  '34672,Día de la Mujer\n',
#  '33165,Día de la Madre\n',
#  '32331,Día del Padre\n',
#  '30766,Día del Idioma\n',
#  '29476,Día del Profesor\n',
#  '29103,Color\n',
#  '29975,Amarillo\n',
#  '33315,Azul\n',
#  '31612,Rojo\n',
#  '28335,Verde\n',
#  '29429,Naranja\n',
#  '29816,Violeta\n',
#  '34631,Café\n',
#  '27612,Negro\n',
#  '27881,Blanco\n',
#  '32552,Gris\n',
#  '31331,Rosado\n',
#  '33572,Caminar\n',
#  '35678,Correr\n',
#  '36453,Nadar\n',
#  '28796,Jugar\n',
#  '34171,Comer\n',
#  '35682,Dormir\n',
#  '30465,Limpiar\n',
#  '35139,Bañar\n',
#  '32482,Hora\n',
#  '28196,Minuto\n',
#  '33526,Segundo\n',
#  '28970,Día\n',
#  '36844,Día festivo\n',
#  '34830,Semana\n',
#  '30427,Mes\n',
#  '35185,Año\n',
#  '35080,Enero\n',
#  '36650,Febrero\n',
#  '33534,Marzo\n',
#  '34464,Abril\n',
#  '32143,Mayo\n',
#  '28276,Junio\n',
#  '34839,Julio\n',
#  '31535,Agosto\n',
#  '29672,Septiembre\n',
#  '31537,Octubre\n',
#  '36486,Noviembre\n',
#  '33543,Diciembre\n',
#  '28290,Lunes\n',
#  '34474,Martes\n',
#  '28545,Miércoles\n',
#  '36588,Jueves\n',
#  '28769,Viernes\n',
#  '32507,Sábado\n',
#  '32673,Domingo\n',
#  '31141,Mañana\n',
#  '28316,Tarde\n',
#  '31143,Noche\n',
#  '36871,Ayer\n',
#  '36410,Hoy\n',
#  '29626,Buenos días\n',
#  '36034,Buenas tardes\n',
#  '36257,Buenas noches\n',
#  '31493,Hola\n',
#  '35749,¿Cómo estás?\n',
#  '36260,Adiós\n',
#  '33971,Bienvenido\n',
#  '30398,Gracias\n',
#  '33773,Camisa\n',
#  '28465,Pantalón\n',
#  '33775,Blusa\n',
#  '31464,Falda\n',
#  '35960,Saco\n',
#  '35322,Gorro\n',
#  '33470,Sombrero\n',
#  '28893,Zapato\n',
#  '33781,Medias\n',
#  '33782,Guantes\n',
#  '28474,Pantaloneta\n',
#  '35618,Computador\n',
#  '32473,Celular\n',
#  '36316,Teclado\n',
#  '31106,Ratón\n',
#  '31807,Pantalla\n',
#  '36000,Facebook\n',
#  '28183,WhatsApp\n',
#  '31110,Televisión\n',
#  '32480,Radio\n',
#  '32481,Internet\n',
#  '31284,Perro\n',
#  '33369,Gato\n',
#  '29130,Gallina\n',
#  '33820,Conejo\n',
#  '32820,Sapo\n',
#  '29275,Pato\n',
#  '33283,Ballena\n',
#  '27843,Cerdo\n',
#  '32980,Pollito\n',
#  '28285,León\n',
#  '27414,Tigre\n',
#  '33828,Delfín\n',
#  '32030,Tiburón\n',
#  '34231,Oso\n',
#  '27418,Caballo\n',
#  '34603,Tortuga\n',
#  '32034,Serpiente\n',
#  '33085,Vaca\n',
#  '29226,Pez\n',
#  '27424,Ratón\n',
#  '33921,Mono\n',
#  '28309,Mico\n',
#  '30106,Cocodrilo\n',
#  '28313,Oveja\n',
#  '33733,Elefante\n',
#  '29413,Pájaro\n',
#  '34947,Mariposa\n',
#  '27593,Jirafa\n',
#  '28157,Caracol\n',
#  '28999,Moto\n',
#  '36412,Carro\n',
#  '34152,Bicicleta\n',
#  '32517,Bus\n',
#  '35665,Tren\n',
#  '34491,Avión\n',
#  '36603,Ambulancia\n',
#  '27357,Aretes\n',
#  '27370,Reloj\n',
#  '34186,Cadena\n',
#  '29724,Gafas\n',
#  '34894,Anillo\n',
#  '33851,Correa\n',
#  '27518,Pulsera\n']

# %% [markdown]
# Confusion matrix
# TP = Evaluated vowel and annotated vowel
# TN = Evaluated vowel and non annotated vowel
# FP = Evaluated non vowel and annotated vowel
# FN = Evaluated non vowel and annotated non vowel
# WV = Evaluated vowel but not the vowel we want

# %%
global_tp = 0
global_tn = 0
global_fp = 0
global_fn = 0
global_wv = 0


def evaluate_vowel_in_time(vowels_intervals, evaluated_vowel, t):
    for t_min, t_max, vowel in vowels_intervals:
        if t_min < t < t_max:
            if evaluated_vowel == vowel:
                return True
    return False
results = list()
for annotation in annotations:
    record_name, transcription = annotation.replace("\n", "").split(",")
    record_path = os.path.join(base_folder, wav_folder, f"{record_name}.wav")
    transcription_file = os.path.join(base_folder, annotations_folder, f"{record_name}.TextGrid")
    if os.path.exists(transcription_file):
        tp = 0
        tn = 0
        fp = 0
        fn = 0
        wv = 0
        current_text_grid = textgrids.TextGrid(transcription_file)
        try:
            print("TRANSCRIPTION:", transcription)
            intervals = current_text_grid[transcription.lower()]
            vowels_intervals = list()
            if os.path.exists(record_path):
                snd = parselmouth.Sound(record_path)
                field_names = ["t", "f1", "f2", "i", "vowel", "distance"]
                for f1, f2, intensity, t in zip(*extract_f1_f2_and_intensity_from_sound(snd)):
                    vowel, distance = get_closer_vowel(f1, f2)
                    vowel_non_vowel, distance = evaluate_non_vocal((vowel, distance))
                    # Tengo lag mental, esto no es eficiente, no me juzguen
                    for interval in intervals:
                        if interval.xmin < t < interval.xmax:
                            phoneme_annotation = interval.text.strip()
                            if phoneme_annotation == vowel_non_vowel:
                                tp += 1
                            elif vowel_non_vowel in vowels and phoneme_annotation not in vowels:
                                tn += 1
                            elif vowel_non_vowel.startswith("non_vocal_") and phoneme_annotation in vowels:
                                fp += 1
                            elif vowel_non_vowel.startswith("non_vocal_") and phoneme_annotation not in vowels:
                                fn += 1
                            else:
                                wv += 1
                                tp += 1
            else:
                print(f"Record file {record_path} does not exists")
        except KeyError:
            pass
        print("Before appending")
        results.append({
            "transcription": transcription,
            "tp": tp,
            "tn": tn,
            "fp": fp,
            "fn": fn,
            "wv": wv
        })
        global_tp += tp
        global_tn += tn
        global_fp += fp
        global_fn += fn
        global_wv += wv


results.append({
    "transcription": "GLOBAL",
    "tp": global_tp,
    "tn": global_tn,
    "fp": global_fp,
    "fn": global_fn,
    "wv": global_wv
})
results
# Out:
# TRANSCRIPTION: Arete
# Before appending
# TRANSCRIPTION: Reloj
# Before appending
# TRANSCRIPTION: Cadena
# Before appending
# TRANSCRIPTION: Gafas
# Before appending
# TRANSCRIPTION: Anillo
# Before appending
# TRANSCRIPTION: Pollo
# Before appending
# TRANSCRIPTION: Pepino
# Before appending
# TRANSCRIPTION: Miedo
# Before appending
# TRANSCRIPTION: Odio
# Before appending
# TRANSCRIPTION: Jugo
# Before appending
# TRANSCRIPTION: Leche
# Before appending
# TRANSCRIPTION: Limonada
# Before appending
# TRANSCRIPTION: Estudiante
# Before appending
# TRANSCRIPTION: Conductor
# Before appending
# TRANSCRIPTION: Chef
# Before appending
# TRANSCRIPTION: Odontólogo
# Before appending
# TRANSCRIPTION: Pintor
# Before appending
# TRANSCRIPTION: Familia
# Before appending
# TRANSCRIPTION: Papá
# Before appending
# TRANSCRIPTION: Hermana
# Before appending
# TRANSCRIPTION: Abuela
# Before appending
# TRANSCRIPTION: Amiga
# Before appending
# TRANSCRIPTION: Novia
# Before appending
# TRANSCRIPTION: Esposo
# Before appending
# TRANSCRIPTION: Nieta
# Before appending
# TRANSCRIPTION: Borrador
# Before appending
# TRANSCRIPTION: Cuaderno
# Before appending
# TRANSCRIPTION: Maletín
# Before appending
# TRANSCRIPTION: Baloncesto
# Before appending
# TRANSCRIPTION: Voleibol
# Before appending
# TRANSCRIPTION: Gimnasio
# Before appending
# TRANSCRIPTION: Droguería
# Before appending
# TRANSCRIPTION: Trabajo
# Before appending
# TRANSCRIPTION: Cocina
# Before appending
# TRANSCRIPTION: Ojo
# Before appending
# TRANSCRIPTION: Boca
# Before appending
# TRANSCRIPTION: Oreja
# Before appending
# TRANSCRIPTION: Cabello
# Before appending
# TRANSCRIPTION: Manos
# Before appending
# TRANSCRIPTION: Piernas
# Before appending
# TRANSCRIPTION: Cinco
# Before appending
# TRANSCRIPTION: Seis
# Before appending
# TRANSCRIPTION: Ocho
# Before appending
# TRANSCRIPTION: Cuadrado
# Before appending
# TRANSCRIPTION: Rectángulo
# Before appending
# TRANSCRIPTION: Perro Caliente
# Before appending
# TRANSCRIPTION: Pizza
# Before appending
# TRANSCRIPTION: Arroz
# Before appending
# TRANSCRIPTION: Arepa
# Before appending
# TRANSCRIPTION: Naranja
# Before appending
# TRANSCRIPTION: Mora
# Before appending
# TRANSCRIPTION: Banano
# Before appending
# TRANSCRIPTION: Lulo
# Before appending
# TRANSCRIPTION: Flaco
# Before appending
# TRANSCRIPTION: Abajo
# Before appending
# TRANSCRIPTION: Lejos
# Before appending
# TRANSCRIPTION: Rápido
# Before appending
# TRANSCRIPTION: Lento
# Before appending
# TRANSCRIPTION: Menor
# Before appending
# TRANSCRIPTION: Día del Niño
# Before appending
# TRANSCRIPTION: Halloween
# Before appending
# TRANSCRIPTION: Día del Profesor
# Before appending
# TRANSCRIPTION: Color
# Before appending
# TRANSCRIPTION: Verde
# Before appending
# TRANSCRIPTION: Naranja
# Before appending
# TRANSCRIPTION: Violeta
# Before appending
# TRANSCRIPTION: Negro
# Before appending
# TRANSCRIPTION: Blanco
# Before appending
# TRANSCRIPTION: Jugar
# Before appending
# TRANSCRIPTION: Minuto
# Before appending
# TRANSCRIPTION: Día
# Before appending
# TRANSCRIPTION: Junio
# Before appending
# TRANSCRIPTION: Septiembre
# Before appending
# TRANSCRIPTION: Lunes
# Before appending
# TRANSCRIPTION: Miércoles
# Before appending
# TRANSCRIPTION: Viernes
# Before appending
# TRANSCRIPTION: Tarde
# Before appending
# TRANSCRIPTION: Buenos días
# Before appending
# TRANSCRIPTION: Pantalón
# Before appending
# TRANSCRIPTION: Zapato
# Before appending
# TRANSCRIPTION: Pantaloneta
# Before appending
# TRANSCRIPTION: WhatsApp
# Before appending
# TRANSCRIPTION: Gallina
# Before appending
# TRANSCRIPTION: Pato
# Before appending
# TRANSCRIPTION: Cerdo
# Before appending
# TRANSCRIPTION: León
# Before appending
# TRANSCRIPTION: Tigre
# Before appending
# TRANSCRIPTION: Caballo
# Before appending
# TRANSCRIPTION: Pez
# Before appending
# TRANSCRIPTION: Ratón
# Before appending
# TRANSCRIPTION: Mico
# Before appending
# TRANSCRIPTION: Oveja
# Before appending
# TRANSCRIPTION: Pájaro
# Before appending
# TRANSCRIPTION: Jirafa
# Before appending
# TRANSCRIPTION: Caracol
# Before appending
# TRANSCRIPTION: Moto
# Before appending
# TRANSCRIPTION: Aretes
# Before appending
# TRANSCRIPTION: Reloj
# Before appending
# TRANSCRIPTION: Gafas
# Before appending
# TRANSCRIPTION: Pulsera
# Before appending
# [{'transcription': 'Arete', 'tp': 2, 'tn': 44, 'fp': 34, 'fn': 118, 'wv': 0},
#  {'transcription': 'Reloj', 'tp': 9, 'tn': 41, 'fp': 15, 'fn': 174, 'wv': 1},
#  {'transcription': 'Cadena', 'tp': 17, 'tn': 108, 'fp': 64, 'fn': 50, 'wv': 8},
#  {'transcription': 'Gafas', 'tp': 9, 'tn': 115, 'fp': 20, 'fn': 75, 'wv': 9},
#  {'transcription': 'Anillo', 'tp': 11, 'tn': 105, 'fp': 37, 'fn': 86, 'wv': 3},
#  {'transcription': 'Pollo', 'tp': 14, 'tn': 72, 'fp': 23, 'fn': 89, 'wv': 10},
#  {'transcription': 'Pepino', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Miedo', 'tp': 10, 'tn': 90, 'fp': 60, 'fn': 264, 'wv': 10},
#  {'transcription': 'Odio', 'tp': 9, 'tn': 37, 'fp': 62, 'fn': 111, 'wv': 5},
#  {'transcription': 'Jugo', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Leche', 'tp': 9, 'tn': 31, 'fp': 36, 'fn': 122, 'wv': 9},
#  {'transcription': 'Limonada',
#   'tp': 12,
#   'tn': 53,
#   'fp': 53,
#   'fn': 224,
#   'wv': 3},
#  {'transcription': 'Estudiante',
#   'tp': 43,
#   'tn': 52,
#   'fp': 50,
#   'fn': 115,
#   'wv': 25},
#  {'transcription': 'Conductor',
#   'tp': 21,
#   'tn': 92,
#   'fp': 52,
#   'fn': 279,
#   'wv': 2},
#  {'transcription': 'Chef', 'tp': 5, 'tn': 28, 'fp': 19, 'fn': 238, 'wv': 0},
#  {'transcription': 'Odontólogo', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Pintor', 'tp': 6, 'tn': 140, 'fp': 32, 'fn': 82, 'wv': 6},
#  {'transcription': 'Familia',
#   'tp': 6,
#   'tn': 21,
#   'fp': 113,
#   'fn': 150,
#   'wv': 0},
#  {'transcription': 'Papá', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Hermana',
#   'tp': 10,
#   'tn': 60,
#   'fp': 56,
#   'fn': 257,
#   'wv': 0},
#  {'transcription': 'Abuela', 'tp': 26, 'tn': 62, 'fp': 69, 'fn': 226, 'wv': 4},
#  {'transcription': 'Amiga', 'tp': 10, 'tn': 22, 'fp': 44, 'fn': 122, 'wv': 2},
#  {'transcription': 'Novia', 'tp': 8, 'tn': 38, 'fp': 49, 'fn': 206, 'wv': 4},
#  {'transcription': 'Esposo', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Nieta', 'tp': 19, 'tn': 39, 'fp': 45, 'fn': 177, 'wv': 11},
#  {'transcription': 'Borrador',
#   'tp': 13,
#   'tn': 49,
#   'fp': 67,
#   'fn': 131,
#   'wv': 1},
#  {'transcription': 'Cuaderno',
#   'tp': 10,
#   'tn': 126,
#   'fp': 46,
#   'fn': 119,
#   'wv': 8},
#  {'transcription': 'Maletín', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Baloncesto',
#   'tp': 19,
#   'tn': 56,
#   'fp': 64,
#   'fn': 305,
#   'wv': 3},
#  {'transcription': 'Voleibol', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Gimnasio',
#   'tp': 8,
#   'tn': 68,
#   'fp': 74,
#   'fn': 130,
#   'wv': 6},
#  {'transcription': 'Droguería', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Trabajo', 'tp': 8, 'tn': 29, 'fp': 86, 'fn': 270, 'wv': 2},
#  {'transcription': 'Cocina', 'tp': 14, 'tn': 42, 'fp': 56, 'fn': 168, 'wv': 0},
#  {'transcription': 'Ojo', 'tp': 2, 'tn': 132, 'fp': 51, 'fn': 34, 'wv': 2},
#  {'transcription': 'Boca', 'tp': 18, 'tn': 32, 'fp': 35, 'fn': 113, 'wv': 0},
#  {'transcription': 'Oreja', 'tp': 22, 'tn': 64, 'fp': 50, 'fn': 185, 'wv': 6},
#  {'transcription': 'Cabello',
#   'tp': 17,
#   'tn': 49,
#   'fp': 42,
#   'fn': 254,
#   'wv': 11},
#  {'transcription': 'Manos', 'tp': 4, 'tn': 51, 'fp': 34, 'fn': 109, 'wv': 4},
#  {'transcription': 'Piernas', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Cinco', 'tp': 10, 'tn': 90, 'fp': 66, 'fn': 135, 'wv': 5},
#  {'transcription': 'Seis', 'tp': 4, 'tn': 120, 'fp': 27, 'fn': 68, 'wv': 0},
#  {'transcription': 'Ocho', 'tp': 24, 'tn': 21, 'fp': 63, 'fn': 213, 'wv': 17},
#  {'transcription': 'Cuadrado',
#   'tp': 72,
#   'tn': 40,
#   'fp': 248,
#   'fn': 84,
#   'wv': 61},
#  {'transcription': 'Rectángulo', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Perro Caliente',
#   'tp': 0,
#   'tn': 0,
#   'fp': 0,
#   'fn': 0,
#   'wv': 0},
#  {'transcription': 'Pizza', 'tp': 1, 'tn': 55, 'fp': 36, 'fn': 229, 'wv': 1},
#  {'transcription': 'Arroz', 'tp': 15, 'tn': 58, 'fp': 35, 'fn': 254, 'wv': 0},
#  {'transcription': 'Arepa', 'tp': 26, 'tn': 50, 'fp': 54, 'fn': 273, 'wv': 0},
#  {'transcription': 'Naranja', 'tp': 9, 'tn': 53, 'fp': 52, 'fn': 125, 'wv': 0},
#  {'transcription': 'Mora', 'tp': 8, 'tn': 76, 'fp': 44, 'fn': 111, 'wv': 1},
#  {'transcription': 'Banano', 'tp': 9, 'tn': 119, 'fp': 38, 'fn': 114, 'wv': 2},
#  {'transcription': 'Lulo', 'tp': 11, 'tn': 51, 'fp': 59, 'fn': 282, 'wv': 4},
#  {'transcription': 'Flaco', 'tp': 5, 'tn': 81, 'fp': 61, 'fn': 133, 'wv': 5},
#  {'transcription': 'Abajo', 'tp': 1, 'tn': 54, 'fp': 79, 'fn': 187, 'wv': 0},
#  {'transcription': 'Lejos', 'tp': 21, 'tn': 72, 'fp': 18, 'fn': 149, 'wv': 0},
#  {'transcription': 'Rápido', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Lento', 'tp': 18, 'tn': 77, 'fp': 36, 'fn': 88, 'wv': 10},
#  {'transcription': 'Menor', 'tp': 24, 'tn': 70, 'fp': 48, 'fn': 77, 'wv': 5},
#  {'transcription': 'Día del Niño',
#   'tp': 0,
#   'tn': 0,
#   'fp': 0,
#   'fn': 0,
#   'wv': 0},
#  {'transcription': 'Halloween',
#   'tp': 5,
#   'tn': 118,
#   'fp': 60,
#   'fn': 118,
#   'wv': 4},
#  {'transcription': 'Día del Profesor',
#   'tp': 0,
#   'tn': 0,
#   'fp': 0,
#   'fn': 0,
#   'wv': 0},
#  {'transcription': 'Color', 'tp': 3, 'tn': 64, 'fp': 36, 'fn': 157, 'wv': 3},
#  {'transcription': 'Verde', 'tp': 1, 'tn': 69, 'fp': 36, 'fn': 195, 'wv': 0},
#  {'transcription': 'Naranja',
#   'tp': 22,
#   'tn': 17,
#   'fp': 38,
#   'fn': 152,
#   'wv': 0},
#  {'transcription': 'Violeta',
#   'tp': 10,
#   'tn': 46,
#   'fp': 44,
#   'fn': 221,
#   'wv': 3},
#  {'transcription': 'Negro', 'tp': 19, 'tn': 83, 'fp': 54, 'fn': 165, 'wv': 7},
#  {'transcription': 'Blanco', 'tp': 9, 'tn': 55, 'fp': 35, 'fn': 243, 'wv': 1},
#  {'transcription': 'Jugar', 'tp': 22, 'tn': 39, 'fp': 39, 'fn': 98, 'wv': 7},
#  {'transcription': 'Minuto', 'tp': 1, 'tn': 81, 'fp': 82, 'fn': 239, 'wv': 1},
#  {'transcription': 'Día', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Junio', 'tp': 17, 'tn': 86, 'fp': 82, 'fn': 259, 'wv': 14},
#  {'transcription': 'Septiembre',
#   'tp': 13,
#   'tn': 70,
#   'fp': 59,
#   'fn': 251,
#   'wv': 2},
#  {'transcription': 'Lunes', 'tp': 23, 'tn': 87, 'fp': 22, 'fn': 210, 'wv': 17},
#  {'transcription': 'Miércoles', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Viernes', 'tp': 2, 'tn': 23, 'fp': 33, 'fn': 202, 'wv': 0},
#  {'transcription': 'Tarde', 'tp': 20, 'tn': 82, 'fp': 41, 'fn': 117, 'wv': 0},
#  {'transcription': 'Buenos días', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Pantalón', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Zapato', 'tp': 12, 'tn': 80, 'fp': 63, 'fn': 105, 'wv': 6},
#  {'transcription': 'Pantaloneta',
#   'tp': 27,
#   'tn': 117,
#   'fp': 45,
#   'fn': 131,
#   'wv': 7},
#  {'transcription': 'WhatsApp',
#   'tp': 18,
#   'tn': 80,
#   'fp': 67,
#   'fn': 238,
#   'wv': 8},
#  {'transcription': 'Gallina', 'tp': 2, 'tn': 15, 'fp': 89, 'fn': 123, 'wv': 2},
#  {'transcription': 'Pato', 'tp': 5, 'tn': 37, 'fp': 24, 'fn': 132, 'wv': 5},
#  {'transcription': 'Cerdo', 'tp': 28, 'tn': 62, 'fp': 19, 'fn': 274, 'wv': 3},
#  {'transcription': 'León', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Tigre', 'tp': 1, 'tn': 64, 'fp': 25, 'fn': 67, 'wv': 1},
#  {'transcription': 'Caballo', 'tp': 9, 'tn': 75, 'fp': 31, 'fn': 42, 'wv': 0},
#  {'transcription': 'Pez', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Ratón', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Mico', 'tp': 10, 'tn': 87, 'fp': 29, 'fn': 236, 'wv': 1},
#  {'transcription': 'Oveja', 'tp': 15, 'tn': 89, 'fp': 50, 'fn': 167, 'wv': 1},
#  {'transcription': 'Pájaro', 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0, 'wv': 0},
#  {'transcription': 'Jirafa',
#   'tp': 5,
#   'tn': 129,
#   'fp': 101,
#   'fn': 209,
#   'wv': 3},
#  {'transcription': 'Caracol',
#   'tp': 9,
#   'tn': 131,
#   'fp': 46,
#   'fn': 115,
#   'wv': 4},
#  {'transcription': 'Moto', 'tp': 5, 'tn': 72, 'fp': 52, 'fn': 90, 'wv': 3},
#  {'transcription': 'Aretes', 'tp': 6, 'tn': 45, 'fp': 37, 'fn': 172, 'wv': 1},
#  {'transcription': 'Reloj', 'tp': 1, 'tn': 71, 'fp': 24, 'fn': 61, 'wv': 1},
#  {'transcription': 'Gafas', 'tp': 0, 'tn': 82, 'fp': 29, 'fn': 149, 'wv': 0},
#  {'transcription': 'Pulsera',
#   'tp': 21,
#   'tn': 78,
#   'fp': 72,
#   'fn': 273,
#   'wv': 1},
#  {'transcription': 'GLOBAL',
#   'tp': 990,
#   'tn': 5269,
#   'fp': 3966,
#   'fn': 12716,
#   'wv': 372}]

# %%
performance_dir = "performance"
os.makedirs(performance_dir, exist_ok=True)

with open(os.path.join(performance_dir, f"performance_kmeans.csv"), "w+") as f:
    headers = ["transcription", "tp", "tn", "fp", "fn", "wv"]
    dict_writer = csv.DictWriter(f, headers)
    dict_writer.writeheader()
    dict_writer.writerows(results)

# %%
# =(B102+E102)/(SUM(B102:E102))
