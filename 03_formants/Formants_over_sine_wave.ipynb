# %% [markdown]
# # Formants

# %%
import numpy as np
from scipy import signal
from scipy.io import wavfile
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap

# %%
plt.rcParams["figure.figsize"] = (12, 9)

# %%
frequency, wave = wavfile.read("A_440.wav")
# Out:
# <ipython-input-3-792119757e5c>:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   frequency, wave = wavfile.read("A_440.wav")

# %%
frequency
# Out:
# 16000

# %%
wave
# Out:
# array([     0,   4507,   8880, ..., -12989,  -8879,  -4508], dtype=int16)

# %%
plt.plot(wave)

# %%
frequencies, time, spectrogram = signal.spectrogram(wave, frequency)
spectrogram.shape
# Out:
# (129, 71)

# %%
frequencies.shape
# Out:
# (129,)

# %%
time
# Out:
# array([0.008, 0.022, 0.036, 0.05 , 0.064, 0.078, 0.092, 0.106, 0.12 ,
#        0.134, 0.148, 0.162, 0.176, 0.19 , 0.204, 0.218, 0.232, 0.246,
#        0.26 , 0.274, 0.288, 0.302, 0.316, 0.33 , 0.344, 0.358, 0.372,
#        0.386, 0.4  , 0.414, 0.428, 0.442, 0.456, 0.47 , 0.484, 0.498,
#        0.512, 0.526, 0.54 , 0.554, 0.568, 0.582, 0.596, 0.61 , 0.624,
#        0.638, 0.652, 0.666, 0.68 , 0.694, 0.708, 0.722, 0.736, 0.75 ,
#        0.764, 0.778, 0.792, 0.806, 0.82 , 0.834, 0.848, 0.862, 0.876,
#        0.89 , 0.904, 0.918, 0.932, 0.946, 0.96 , 0.974, 0.988])

# %%
time.shape
# Out:
# (71,)

# %%
spectrogram
# Out:
# array([[2.5724762e+01, 2.2122517e+03, 2.0551741e+03, ..., 1.0389327e+03,
#         3.2279645e+02, 2.6508994e+03],
#        [3.0637554e+03, 3.4245769e+03, 3.3484331e+03, ..., 3.1867710e+03,
#         3.1239241e+03, 3.4813152e+03],
#        [1.2112132e+04, 9.7628467e+03, 1.0031842e+04, ..., 1.1111267e+04,
#         1.1770796e+04, 9.3229092e+03],
#        ...,
#        [4.7866525e-03, 1.3699399e-04, 3.1256035e-03, ..., 3.3314251e-03,
#         3.1975100e-03, 5.4671937e-03],
#        [1.0379946e-03, 2.0320162e-03, 5.4414291e-03, ..., 8.8345940e-04,
#         5.6824391e-03, 6.7901448e-03],
#        [3.6380272e-05, 4.7272812e-03, 1.2823336e-03, ..., 1.0031037e-04,
#         7.0631625e-03, 1.2807011e-03]], dtype=float32)

# %%
spectrogram.shape
# Out:
# (129, 71)

# %%
cmap=get_cmap("coolwarm")

# %%
plt.pcolormesh(time, frequencies, spectrogram,cmap=cmap)

# %%
specgram, frequencies_specgram, time_specgram, im_specgram = plt.specgram(wave, Fs=frequency)
plt.axvline(time_specgram[90])

# %%
wave.shape
# Out:
# (16000,)

# %%
plt.subplot(211)
plt.plot(wave)
plt.xlabel('Sample')
plt.ylabel('Amplitude')

# Plot the spectrogram
plt.subplot(212)
plt.pcolormesh(time, frequencies, spectrogram, cmap=cmap)
plt.axvline(time[50])
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
local_maxs = signal.argrelextrema(spectrogram, np.greater, axis=1)
local_maxs
# Out:
# (array([  0,   0,   0, ..., 128, 128, 128]),
#  array([ 1,  5,  8, ..., 64, 66, 69]))

# %%
plt.plot(frequencies, spectrogram.T[50])

# %%
maxs_i = np.apply_along_axis(np.argmax, 0, spectrogram)
maxs_i.shape
# Out:
# (71,)

# %%
maxs_i
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7])

# %%
frequencies[maxs_i]
# Out:
# array([437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5,
#        437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5, 437.5])

# %%
maxs = np.apply_along_axis(np.amax, 0, spectrogram)
maxs.shape
# Out:
# (71,)

# %%
maxs_i[maxs>10]
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7])

# %%
maxs
# Out:
# array([4980604. , 4960872. , 4963544.5, 4981002.5, 4963466.5, 4960939.5,
#        4980630. , 4966387. , 4958830.5, 4979506. , 4969459.5, 4957335.5,
#        4977701.5, 4972479. , 4956564.5, 4975341.5, 4975264.5, 4956546.5,
#        4972561.5, 4977645. , 4957310. , 4969542. , 4979463.5, 4958781. ,
#        4966468.5, 4980605. , 4960876. , 4963543.5, 4981005. , 4963461. ,
#        4960939. , 4980622.5, 4966392.5, 4958828. , 4979509. , 4969460.5,
#        4957335. , 4977701.5, 4972483. , 4956560.5, 4975338. , 4975271. ,
#        4956546. , 4972568. , 4977650. , 4957306. , 4969547. , 4979466. ,
#        4958780. , 4966476.5, 4980604. , 4960874. , 4963545. , 4980993. ,
#        4963467. , 4960935.5, 4980626. , 4966391. , 4958830. , 4979506.5,
#        4969457. , 4957334. , 4977701.5, 4972482.5, 4956560. , 4975345. ,
#        4975269. , 4956549. , 4972555.5, 4977652.5, 4957299.5],
#       dtype=float32)

# %%
hpf_maxs_i = (maxs>10).astype(np.int) * maxs_i
hpf_maxs_i
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7])

# %%
plt.plot(maxs)

# %%
plt.pcolormesh(time, frequencies, spectrogram, cmap=cmap)
plt.plot(time,frequencies[maxs_i],"--",color="orange")
plt.axvline(time[50])
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.pcolormesh(time, frequencies, spectrogram, cmap=cmap)
plt.plot(time,frequencies[hpf_maxs_i],"--",color="orange")
plt.axvline(time[50])
plt.xlabel('Time')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
signal.argrelextrema(spectrogram.T[50], np.greater)
# Out:
# (array([  5,   7,  16,  20,  24,  28,  32,  36,  40,  44,  48,  52,  56,
#          60,  64,  68,  72,  76,  79,  82,  84,  88,  90,  92,  96,  99,
#         101, 105, 107, 110, 113, 116, 120, 122, 125, 127]),)

# %%
signal.find_peaks(spectrogram.T[50])
# Out:
# (array([  5,   7,  16,  20,  24,  28,  32,  36,  40,  44,  48,  52,  56,
#          60,  64,  68,  72,  76,  79,  82,  84,  88,  90,  92,  96,  99,
#         101, 105, 107, 110, 113, 116, 120, 122, 125, 127]), {})

# %%
specgram.shape
# Out:
# (129, 124)

# %%
plt.plot(frequencies_specgram, specgram.T[90])

# %%
signal.argrelextrema(specgram.T[50], np.greater)
# Out:
# (array([  7,  37,  39,  41,  45,  48,  51,  54,  56,  61,  65,  68,  71,
#          73,  75,  79,  86,  90,  94,  97, 101, 103, 105, 107, 111, 116,
#         120, 122, 126]),)
