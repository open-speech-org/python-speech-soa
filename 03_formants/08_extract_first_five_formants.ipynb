# %%
import os
import csv

import parselmouth

import textgrids

import numpy as np

# %%
n_formants = 5

def extract_formants_and_intensity_from_sound(snd):
    formants = snd.to_formant_burg()
    intensity = snd.to_intensity()
    formant_list = [list() for _ in range(n_formants)]
    intensity_list = list()
    for t in formants.t_grid():
        for f_n in range(n_formants):
            formant_list[f_n].append(formants.get_value_at_time(f_n + 1,t))
        intensity_list.append(intensity.get_value(t))

    return *formant_list, intensity_list, formants.t_grid()

# %%
base_folder = "words_annotations"
annotations_folder = "annotations"
wav_folder = "wav"

formants_dir = "all_formants_observed_formants_first_5_formants"
os.makedirs(formants_dir, exist_ok=True)

# %%
transcription_file = "words_annotations/word_map.txt"
with open(transcription_file) as af:
    annotations = af.readlines()
annotations
# Out:
# ['27356,Arete\n',
#  '27358,Reloj\n',
#  '27361,Cadena\n',
#  '27364,Gafas\n',
#  '27365,Anillo\n',
#  '27387,Pollo\n',
#  '36677,Papa\n',
#  '32540,Yuca\n',
#  '33582,Tomate\n',
#  '31873,Zanahoria\n',
#  '36438,Cebolla\n',
#  '35472,Cilantro\n',
#  '29029,Pepino\n',
#  '32621,Habichuela\n',
#  '36271,Te amo\n',
#  '36358,Me gusta\n',
#  '31500,Quiero\n',
#  '35159,Feliz\n',
#  '34100,Triste\n',
#  '28102,Miedo\n',
#  '28728,Odio\n',
#  '32467,Culpa\n',
#  '33981,Enojo\n',
#  '35165,Aburrido\n',
#  '35616,Celos\n',
#  '36265,Amor\n',
#  '34617,Agua\n',
#  '33307,Café\n',
#  '27436,Jugo\n',
#  '29420,Leche\n',
#  '31317,Avena\n',
#  '34014,Chocolate\n',
#  '29809,Limonada\n',
#  '30373,Bombero\n',
#  '32784,Medico\n',
#  '30538,Profesor\n',
#  '28699,Estudiante\n',
#  '32438,Interpretador\n',
#  '28066,Conductor\n',
#  '36798,Enfermero\n',
#  '30380,Cantante\n',
#  '32791,Carpintero\n',
#  '29617,Chef\n',
#  '33954,Fotógrafo\n',
#  '31077,Músico\n',
#  '28487,Odontólogo\n',
#  '31485,Peluquero\n',
#  '36245,Periodista\n',
#  '33962,Piloto\n',
#  '36249,Policía\n',
#  '28492,Pintor\n',
#  '29182,Familia\n',
#  '28186,Papá\n',
#  '33026,Mamá\n',
#  '34274,Hermano\n',
#  '27893,Hermana\n',
#  '30737,Tío\n',
#  '34527,Tía\n',
#  '34040,Primo\n',
#  '33032,Prima\n',
#  '33130,Abuelo\n',
#  '27899,Abuela\n',
#  '34652,Hijo\n',
#  '34283,Hija\n',
#  '32572,Amigo\n',
#  '29455,Amiga\n',
#  '33039,Novio\n',
#  '29843,Novia\n',
#  '27640,Esposo\n',
#  '32316,Esposa\n',
#  '32837,Nieto\n',
#  '27944,Nieta\n',
#  '31014,Sobrino\n',
#  '34663,Sobrina\n',
#  '34056,Grupo\n',
#  '31650,Persona\n',
#  '35547,Niño\n',
#  '35483,Lápiz\n',
#  '31180,Lapicero\n',
#  '28786,Borrador\n',
#  '30453,Sacapunta\n',
#  '30660,Marcador\n',
#  '33568,Regla\n',
#  '28568,Cuaderno\n',
#  '28364,Maletín\n',
#  '34004,Futbol\n',
#  '27885,Baloncesto\n',
#  '33327,Atletismo\n',
#  '28180,Voleibol\n',
#  '29984,Natación\n',
#  '32689,Colegio\n',
#  '32878,Cine\n',
#  '32879,Hotel\n',
#  '33671,Parque\n',
#  '35870,Aeropuerto\n',
#  '32967,Panadería\n',
#  '31397,Banco\n',
#  '35725,Restaurante\n',
#  '32360,Museo\n',
#  '34335,Biblioteca\n',
#  '32972,Estadio\n',
#  '36156,Zoológico\n',
#  '27694,Gimnasio\n',
#  '35879,Hospital\n',
#  '29956,Universidad\n',
#  '30802,Iglesia\n',
#  '29958,Supermercado\n',
#  '29541,Droguería\n',
#  '32895,Casa\n',
#  '29543,Trabajo\n',
#  '32372,Piscina\n',
#  '30808,Baño\n',
#  '31051,Cuarto\n',
#  '36168,Sala\n',
#  '29905,Cocina\n',
#  '28113,Ojo\n',
#  '30670,Nariz\n',
#  '29346,Boca\n',
#  '29766,Oreja\n',
#  '28020,Cabello\n',
#  '29264,Manos\n',
#  '33271,Brazos\n',
#  '29351,Piernas\n',
#  '34585,Pies\n',
#  '30082,Cabeza\n',
#  '31222,Tronco\n',
#  '35049,Cero\n',
#  '30886,Uno\n',
#  '33764,Dos\n',
#  '30888,Tres\n',
#  '30512,Cuatro\n',
#  '28043,Cinco\n',
#  '28459,Seis\n',
#  '30515,Siete\n',
#  '29592,Ocho\n',
#  '35315,Nueve\n',
#  '31753,Diez\n',
#  '34972,Triangulo\n',
#  '27947,Cuadrado\n',
#  '34551,Circulo\n',
#  '27665,Rectángulo\n',
#  '32338,Línea\n',
#  '34897,Hamburguesa\n',
#  '29729,Perro Caliente\n',
#  '28248,Pizza\n',
#  '31888,Pandebono\n',
#  '31997,Pan\n',
#  '29754,Arroz\n',
#  '30065,Huevos\n',
#  '31892,Carne\n',
#  '33259,Pollo\n',
#  '33352,Pescado\n',
#  '33703,Salchichas\n',
#  '29760,Arepa\n',
#  '33054,Ensalada\n',
#  '33264,Pastel\n',
#  '35454,Manzana\n',
#  '31379,Pera\n',
#  '31669,Mango\n',
#  '34316,Sandia\n',
#  '28606,Naranja\n',
#  '31672,Uva\n',
#  '33661,Piña\n',
#  '27507,Mora\n',
#  '34690,Guanábana\n',
#  '28390,Banano\n',
#  '34692,Fresa\n',
#  '27966,Lulo\n',
#  '31679,Limón\n',
#  '33212,Alto\n',
#  '36101,Bajo\n',
#  '35274,Gordo\n',
#  '28844,Flaco\n',
#  '30162,Mucho\n',
#  '34356,Poco\n',
#  '31598,Arriba\n',
#  '29913,Abajo\n',
#  '31717,Cerca\n',
#  '29915,Lejos\n',
#  '31894,Encima\n',
#  '36181,Debajo\n',
#  '33224,Izquierda\n',
#  '30864,Derecha\n',
#  '32740,Adelante\n',
#  '30173,Atrás\n',
#  '36905,Grande\n',
#  '30868,Mediano\n',
#  '35290,Pequeño\n',
#  '34370,Largo\n',
#  '31436,Corto\n',
#  '32936,Dentro\n',
#  '34742,Fuera\n',
#  '36912,Bonito\n',
#  '35039,Feo\n',
#  '28028,Rápido\n',
#  '28867,Lento\n',
#  '34747,Blando\n',
#  '32754,Duro\n',
#  '36129,Sentarse\n',
#  '31739,Pararse\n',
#  '31740,Mayor\n',
#  '28873,Menor\n',
#  '32410,Igual\n',
#  '32587,Cumpleaños\n',
#  '33641,Navidad\n',
#  '31654,Año nuevo\n',
#  '27488,Día del Niño\n',
#  '28235,Halloween\n',
#  '34672,Día de la Mujer\n',
#  '33165,Día de la Madre\n',
#  '32331,Día del Padre\n',
#  '30766,Día del Idioma\n',
#  '29476,Día del Profesor\n',
#  '29103,Color\n',
#  '29975,Amarillo\n',
#  '33315,Azul\n',
#  '31612,Rojo\n',
#  '28335,Verde\n',
#  '29429,Naranja\n',
#  '29816,Violeta\n',
#  '34631,Café\n',
#  '27612,Negro\n',
#  '27881,Blanco\n',
#  '32552,Gris\n',
#  '31331,Rosado\n',
#  '33572,Caminar\n',
#  '35678,Correr\n',
#  '36453,Nadar\n',
#  '28796,Jugar\n',
#  '34171,Comer\n',
#  '35682,Dormir\n',
#  '30465,Limpiar\n',
#  '35139,Bañar\n',
#  '32482,Hora\n',
#  '28196,Minuto\n',
#  '33526,Segundo\n',
#  '28970,Día\n',
#  '36844,Día festivo\n',
#  '34830,Semana\n',
#  '30427,Mes\n',
#  '35185,Año\n',
#  '35080,Enero\n',
#  '36650,Febrero\n',
#  '33534,Marzo\n',
#  '34464,Abril\n',
#  '32143,Mayo\n',
#  '28276,Junio\n',
#  '34839,Julio\n',
#  '31535,Agosto\n',
#  '29672,Septiembre\n',
#  '31537,Octubre\n',
#  '36486,Noviembre\n',
#  '33543,Diciembre\n',
#  '28290,Lunes\n',
#  '34474,Martes\n',
#  '28545,Miércoles\n',
#  '36588,Jueves\n',
#  '28769,Viernes\n',
#  '32507,Sábado\n',
#  '32673,Domingo\n',
#  '31141,Mañana\n',
#  '28316,Tarde\n',
#  '31143,Noche\n',
#  '36871,Ayer\n',
#  '36410,Hoy\n',
#  '29626,Buenos días\n',
#  '36034,Buenas tardes\n',
#  '36257,Buenas noches\n',
#  '31493,Hola\n',
#  '35749,¿Cómo estás?\n',
#  '36260,Adiós\n',
#  '33971,Bienvenido\n',
#  '30398,Gracias\n',
#  '33773,Camisa\n',
#  '28465,Pantalón\n',
#  '33775,Blusa\n',
#  '31464,Falda\n',
#  '35960,Saco\n',
#  '35322,Gorro\n',
#  '33470,Sombrero\n',
#  '28893,Zapato\n',
#  '33781,Medias\n',
#  '33782,Guantes\n',
#  '28474,Pantaloneta\n',
#  '35618,Computador\n',
#  '32473,Celular\n',
#  '36316,Teclado\n',
#  '31106,Ratón\n',
#  '31807,Pantalla\n',
#  '36000,Facebook\n',
#  '28183,WhatsApp\n',
#  '31110,Televisión\n',
#  '32480,Radio\n',
#  '32481,Internet\n',
#  '31284,Perro\n',
#  '33369,Gato\n',
#  '29130,Gallina\n',
#  '33820,Conejo\n',
#  '32820,Sapo\n',
#  '29275,Pato\n',
#  '33283,Ballena\n',
#  '27843,Cerdo\n',
#  '32980,Pollito\n',
#  '28285,León\n',
#  '27414,Tigre\n',
#  '33828,Delfín\n',
#  '32030,Tiburón\n',
#  '34231,Oso\n',
#  '27418,Caballo\n',
#  '34603,Tortuga\n',
#  '32034,Serpiente\n',
#  '33085,Vaca\n',
#  '29226,Pez\n',
#  '27424,Ratón\n',
#  '33921,Mono\n',
#  '28309,Mico\n',
#  '30106,Cocodrilo\n',
#  '28313,Oveja\n',
#  '33733,Elefante\n',
#  '29413,Pájaro\n',
#  '34947,Mariposa\n',
#  '27593,Jirafa\n',
#  '28157,Caracol\n',
#  '28999,Moto\n',
#  '36412,Carro\n',
#  '34152,Bicicleta\n',
#  '32517,Bus\n',
#  '35665,Tren\n',
#  '34491,Avión\n',
#  '36603,Ambulancia\n',
#  '27357,Aretes\n',
#  '27370,Reloj\n',
#  '34186,Cadena\n',
#  '29724,Gafas\n',
#  '34894,Anillo\n',
#  '33851,Correa\n',
#  '27518,Pulsera\n']

# %%
for annotation in annotations:
    record_name, transcription = annotation.replace("\n", "").split(",")
    record_path = os.path.join(base_folder, wav_folder, f"{record_name}.wav")
    formants_file_path = os.path.join(formants_dir, f"{record_name}-{transcription}.csv")
    text_grid_file = os.path.join(base_folder, annotations_folder, f"{record_name}.TextGrid")
    if os.path.exists(record_path):

        try:
            current_text_grid = textgrids.TextGrid(text_grid_file)
            print("TRANSCRIPTION:", transcription)
            intervals = current_text_grid[transcription.lower()]
            snd = parselmouth.Sound(record_path)
            field_names = ["t", *[f"f_{i+1}" for i in range(n_formants)], "i", "phoneme"]

            with open(formants_file_path, "w+") as tf:
                writer = csv.DictWriter(tf, field_names, dialect='unix')
                writer.writeheader()
                for *formants, intensity, t in zip(*extract_formants_and_intensity_from_sound(snd)):
                    row = {
                        "t": t,
                        "i": intensity,
                    }
                    for interval in intervals:
                        if interval.xmin < t < interval.xmax:
                            row["phoneme"] = interval.text.strip()
                            break
                    for i in range(n_formants):
                        row[f"f_{i+1}"] = formants[i]
                    writer.writerow(row)
        except KeyError:
            print(f"Annotation {transcription} not found")
        except FileNotFoundError:
            print(f"Annotation in {text_grid_file} does not exists")
    else:
        print(f"Record file {record_path} does not exists")
    print(record_name, transcription)
# Out:
# TRANSCRIPTION: Arete
# 27356 Arete
# TRANSCRIPTION: Reloj
# 27358 Reloj
# TRANSCRIPTION: Cadena
# 27361 Cadena
# TRANSCRIPTION: Gafas
# 27364 Gafas
# TRANSCRIPTION: Anillo
# 27365 Anillo
# TRANSCRIPTION: Pollo
# 27387 Pollo
# Annotation in words_annotations/annotations/36677.TextGrid does not exists
# 36677 Papa
# Annotation in words_annotations/annotations/32540.TextGrid does not exists
# 32540 Yuca
# Annotation in words_annotations/annotations/33582.TextGrid does not exists
# 33582 Tomate
# Annotation in words_annotations/annotations/31873.TextGrid does not exists
# 31873 Zanahoria
# Annotation in words_annotations/annotations/36438.TextGrid does not exists
# 36438 Cebolla
# Annotation in words_annotations/annotations/35472.TextGrid does not exists
# 35472 Cilantro
# TRANSCRIPTION: Pepino
# Annotation Pepino not found
# 29029 Pepino
# Annotation in words_annotations/annotations/32621.TextGrid does not exists
# 32621 Habichuela
# Annotation in words_annotations/annotations/36271.TextGrid does not exists
# 36271 Te amo
# Annotation in words_annotations/annotations/36358.TextGrid does not exists
# 36358 Me gusta
# Annotation in words_annotations/annotations/31500.TextGrid does not exists
# 31500 Quiero
# Annotation in words_annotations/annotations/35159.TextGrid does not exists
# 35159 Feliz
# Annotation in words_annotations/annotations/34100.TextGrid does not exists
# 34100 Triste
# TRANSCRIPTION: Miedo
# 28102 Miedo
# TRANSCRIPTION: Odio
# 28728 Odio
# Annotation in words_annotations/annotations/32467.TextGrid does not exists
# 32467 Culpa
# Annotation in words_annotations/annotations/33981.TextGrid does not exists
# 33981 Enojo
# Annotation in words_annotations/annotations/35165.TextGrid does not exists
# 35165 Aburrido
# Annotation in words_annotations/annotations/35616.TextGrid does not exists
# 35616 Celos
# Annotation in words_annotations/annotations/36265.TextGrid does not exists
# 36265 Amor
# Annotation in words_annotations/annotations/34617.TextGrid does not exists
# 34617 Agua
# Annotation in words_annotations/annotations/33307.TextGrid does not exists
# 33307 Café
# TRANSCRIPTION: Jugo
# Annotation Jugo not found
# 27436 Jugo
# TRANSCRIPTION: Leche
# 29420 Leche
# Annotation in words_annotations/annotations/31317.TextGrid does not exists
# 31317 Avena
# Annotation in words_annotations/annotations/34014.TextGrid does not exists
# 34014 Chocolate
# TRANSCRIPTION: Limonada
# 29809 Limonada
# Annotation in words_annotations/annotations/30373.TextGrid does not exists
# 30373 Bombero
# Annotation in words_annotations/annotations/32784.TextGrid does not exists
# 32784 Medico
# Annotation in words_annotations/annotations/30538.TextGrid does not exists
# 30538 Profesor
# TRANSCRIPTION: Estudiante
# 28699 Estudiante
# Annotation in words_annotations/annotations/32438.TextGrid does not exists
# 32438 Interpretador
# TRANSCRIPTION: Conductor
# 28066 Conductor
# Annotation in words_annotations/annotations/36798.TextGrid does not exists
# 36798 Enfermero
# Annotation in words_annotations/annotations/30380.TextGrid does not exists
# 30380 Cantante
# Annotation in words_annotations/annotations/32791.TextGrid does not exists
# 32791 Carpintero
# TRANSCRIPTION: Chef
# 29617 Chef
# Annotation in words_annotations/annotations/33954.TextGrid does not exists
# 33954 Fotógrafo
# Annotation in words_annotations/annotations/31077.TextGrid does not exists
# 31077 Músico
# TRANSCRIPTION: Odontólogo
# Annotation Odontólogo not found
# 28487 Odontólogo
# Annotation in words_annotations/annotations/31485.TextGrid does not exists
# 31485 Peluquero
# Annotation in words_annotations/annotations/36245.TextGrid does not exists
# 36245 Periodista
# Annotation in words_annotations/annotations/33962.TextGrid does not exists
# 33962 Piloto
# Annotation in words_annotations/annotations/36249.TextGrid does not exists
# 36249 Policía
# TRANSCRIPTION: Pintor
# 28492 Pintor
# TRANSCRIPTION: Familia
# 29182 Familia
# TRANSCRIPTION: Papá
# Annotation Papá not found
# 28186 Papá
# Annotation in words_annotations/annotations/33026.TextGrid does not exists
# 33026 Mamá
# Annotation in words_annotations/annotations/34274.TextGrid does not exists
# 34274 Hermano
# TRANSCRIPTION: Hermana
# 27893 Hermana
# Annotation in words_annotations/annotations/30737.TextGrid does not exists
# 30737 Tío
# Annotation in words_annotations/annotations/34527.TextGrid does not exists
# 34527 Tía
# Annotation in words_annotations/annotations/34040.TextGrid does not exists
# 34040 Primo
# Annotation in words_annotations/annotations/33032.TextGrid does not exists
# 33032 Prima
# Annotation in words_annotations/annotations/33130.TextGrid does not exists
# 33130 Abuelo
# TRANSCRIPTION: Abuela
# 27899 Abuela
# Annotation in words_annotations/annotations/34652.TextGrid does not exists
# 34652 Hijo
# Annotation in words_annotations/annotations/34283.TextGrid does not exists
# 34283 Hija
# Annotation in words_annotations/annotations/32572.TextGrid does not exists
# 32572 Amigo
# TRANSCRIPTION: Amiga
# 29455 Amiga
# Annotation in words_annotations/annotations/33039.TextGrid does not exists
# 33039 Novio
# TRANSCRIPTION: Novia
# 29843 Novia
# TRANSCRIPTION: Esposo
# Annotation Esposo not found
# 27640 Esposo
# Annotation in words_annotations/annotations/32316.TextGrid does not exists
# 32316 Esposa
# Annotation in words_annotations/annotations/32837.TextGrid does not exists
# 32837 Nieto
# TRANSCRIPTION: Nieta
# 27944 Nieta
# Annotation in words_annotations/annotations/31014.TextGrid does not exists
# 31014 Sobrino
# Annotation in words_annotations/annotations/34663.TextGrid does not exists
# 34663 Sobrina
# Annotation in words_annotations/annotations/34056.TextGrid does not exists
# 34056 Grupo
# Annotation in words_annotations/annotations/31650.TextGrid does not exists
# 31650 Persona
# Annotation in words_annotations/annotations/35547.TextGrid does not exists
# 35547 Niño
# Annotation in words_annotations/annotations/35483.TextGrid does not exists
# 35483 Lápiz
# Annotation in words_annotations/annotations/31180.TextGrid does not exists
# 31180 Lapicero
# TRANSCRIPTION: Borrador
# 28786 Borrador
# Annotation in words_annotations/annotations/30453.TextGrid does not exists
# 30453 Sacapunta
# Annotation in words_annotations/annotations/30660.TextGrid does not exists
# 30660 Marcador
# Annotation in words_annotations/annotations/33568.TextGrid does not exists
# 33568 Regla
# TRANSCRIPTION: Cuaderno
# 28568 Cuaderno
# TRANSCRIPTION: Maletín
# Annotation Maletín not found
# 28364 Maletín
# Annotation in words_annotations/annotations/34004.TextGrid does not exists
# 34004 Futbol
# TRANSCRIPTION: Baloncesto
# 27885 Baloncesto
# Annotation in words_annotations/annotations/33327.TextGrid does not exists
# 33327 Atletismo
# TRANSCRIPTION: Voleibol
# Annotation Voleibol not found
# 28180 Voleibol
# Annotation in words_annotations/annotations/29984.TextGrid does not exists
# 29984 Natación
# Annotation in words_annotations/annotations/32689.TextGrid does not exists
# 32689 Colegio
# Annotation in words_annotations/annotations/32878.TextGrid does not exists
# 32878 Cine
# Annotation in words_annotations/annotations/32879.TextGrid does not exists
# 32879 Hotel
# Annotation in words_annotations/annotations/33671.TextGrid does not exists
# 33671 Parque
# Annotation in words_annotations/annotations/35870.TextGrid does not exists
# 35870 Aeropuerto
# Annotation in words_annotations/annotations/32967.TextGrid does not exists
# 32967 Panadería
# Annotation in words_annotations/annotations/31397.TextGrid does not exists
# 31397 Banco
# Annotation in words_annotations/annotations/35725.TextGrid does not exists
# 35725 Restaurante
# Annotation in words_annotations/annotations/32360.TextGrid does not exists
# 32360 Museo
# Annotation in words_annotations/annotations/34335.TextGrid does not exists
# 34335 Biblioteca
# Annotation in words_annotations/annotations/32972.TextGrid does not exists
# 32972 Estadio
# Annotation in words_annotations/annotations/36156.TextGrid does not exists
# 36156 Zoológico
# TRANSCRIPTION: Gimnasio
# 27694 Gimnasio
# Annotation in words_annotations/annotations/35879.TextGrid does not exists
# 35879 Hospital
# Annotation in words_annotations/annotations/29956.TextGrid does not exists
# 29956 Universidad
# Annotation in words_annotations/annotations/30802.TextGrid does not exists
# 30802 Iglesia
# Annotation in words_annotations/annotations/29958.TextGrid does not exists
# 29958 Supermercado
# TRANSCRIPTION: Droguería
# Annotation Droguería not found
# 29541 Droguería
# Annotation in words_annotations/annotations/32895.TextGrid does not exists
# 32895 Casa
# TRANSCRIPTION: Trabajo
# 29543 Trabajo
# Annotation in words_annotations/annotations/32372.TextGrid does not exists
# 32372 Piscina
# Annotation in words_annotations/annotations/30808.TextGrid does not exists
# 30808 Baño
# Annotation in words_annotations/annotations/31051.TextGrid does not exists
# 31051 Cuarto
# Annotation in words_annotations/annotations/36168.TextGrid does not exists
# 36168 Sala
# TRANSCRIPTION: Cocina
# 29905 Cocina
# TRANSCRIPTION: Ojo
# 28113 Ojo
# Annotation in words_annotations/annotations/30670.TextGrid does not exists
# 30670 Nariz
# TRANSCRIPTION: Boca
# 29346 Boca
# TRANSCRIPTION: Oreja
# 29766 Oreja
# TRANSCRIPTION: Cabello
# 28020 Cabello
# TRANSCRIPTION: Manos
# 29264 Manos
# Annotation in words_annotations/annotations/33271.TextGrid does not exists
# 33271 Brazos
# TRANSCRIPTION: Piernas
# Annotation Piernas not found
# 29351 Piernas
# Annotation in words_annotations/annotations/34585.TextGrid does not exists
# 34585 Pies
# Annotation in words_annotations/annotations/30082.TextGrid does not exists
# 30082 Cabeza
# Annotation in words_annotations/annotations/31222.TextGrid does not exists
# 31222 Tronco
# Annotation in words_annotations/annotations/35049.TextGrid does not exists
# 35049 Cero
# Annotation in words_annotations/annotations/30886.TextGrid does not exists
# 30886 Uno
# Annotation in words_annotations/annotations/33764.TextGrid does not exists
# 33764 Dos
# Annotation in words_annotations/annotations/30888.TextGrid does not exists
# 30888 Tres
# Annotation in words_annotations/annotations/30512.TextGrid does not exists
# 30512 Cuatro
# TRANSCRIPTION: Cinco
# 28043 Cinco
# TRANSCRIPTION: Seis
# 28459 Seis
# Annotation in words_annotations/annotations/30515.TextGrid does not exists
# 30515 Siete
# TRANSCRIPTION: Ocho
# 29592 Ocho
# Annotation in words_annotations/annotations/35315.TextGrid does not exists
# 35315 Nueve
# Annotation in words_annotations/annotations/31753.TextGrid does not exists
# 31753 Diez
# Annotation in words_annotations/annotations/34972.TextGrid does not exists
# 34972 Triangulo
# TRANSCRIPTION: Cuadrado
# 27947 Cuadrado
# Annotation in words_annotations/annotations/34551.TextGrid does not exists
# 34551 Circulo
# TRANSCRIPTION: Rectángulo
# Annotation Rectángulo not found
# 27665 Rectángulo
# Annotation in words_annotations/annotations/32338.TextGrid does not exists
# 32338 Línea
# Annotation in words_annotations/annotations/34897.TextGrid does not exists
# 34897 Hamburguesa
# TRANSCRIPTION: Perro Caliente
# Annotation Perro Caliente not found
# 29729 Perro Caliente
# TRANSCRIPTION: Pizza
# 28248 Pizza
# Annotation in words_annotations/annotations/31888.TextGrid does not exists
# 31888 Pandebono
# Annotation in words_annotations/annotations/31997.TextGrid does not exists
# 31997 Pan
# TRANSCRIPTION: Arroz
# 29754 Arroz
# Annotation in words_annotations/annotations/30065.TextGrid does not exists
# 30065 Huevos
# Annotation in words_annotations/annotations/31892.TextGrid does not exists
# 31892 Carne
# Annotation in words_annotations/annotations/33259.TextGrid does not exists
# 33259 Pollo
# Annotation in words_annotations/annotations/33352.TextGrid does not exists
# 33352 Pescado
# Annotation in words_annotations/annotations/33703.TextGrid does not exists
# 33703 Salchichas
# TRANSCRIPTION: Arepa
# 29760 Arepa
# Annotation in words_annotations/annotations/33054.TextGrid does not exists
# 33054 Ensalada
# Annotation in words_annotations/annotations/33264.TextGrid does not exists
# 33264 Pastel
# Annotation in words_annotations/annotations/35454.TextGrid does not exists
# 35454 Manzana
# Annotation in words_annotations/annotations/31379.TextGrid does not exists
# 31379 Pera
# Annotation in words_annotations/annotations/31669.TextGrid does not exists
# 31669 Mango
# Annotation in words_annotations/annotations/34316.TextGrid does not exists
# 34316 Sandia
# TRANSCRIPTION: Naranja
# 28606 Naranja
# Annotation in words_annotations/annotations/31672.TextGrid does not exists
# 31672 Uva
# Annotation in words_annotations/annotations/33661.TextGrid does not exists
# 33661 Piña
# TRANSCRIPTION: Mora
# 27507 Mora
# Annotation in words_annotations/annotations/34690.TextGrid does not exists
# 34690 Guanábana
# TRANSCRIPTION: Banano
# 28390 Banano
# Annotation in words_annotations/annotations/34692.TextGrid does not exists
# 34692 Fresa
# TRANSCRIPTION: Lulo
# 27966 Lulo
# Annotation in words_annotations/annotations/31679.TextGrid does not exists
# 31679 Limón
# Annotation in words_annotations/annotations/33212.TextGrid does not exists
# 33212 Alto
# Annotation in words_annotations/annotations/36101.TextGrid does not exists
# 36101 Bajo
# Annotation in words_annotations/annotations/35274.TextGrid does not exists
# 35274 Gordo
# TRANSCRIPTION: Flaco
# 28844 Flaco
# Annotation in words_annotations/annotations/30162.TextGrid does not exists
# 30162 Mucho
# Annotation in words_annotations/annotations/34356.TextGrid does not exists
# 34356 Poco
# Annotation in words_annotations/annotations/31598.TextGrid does not exists
# 31598 Arriba
# TRANSCRIPTION: Abajo
# 29913 Abajo
# Annotation in words_annotations/annotations/31717.TextGrid does not exists
# 31717 Cerca
# TRANSCRIPTION: Lejos
# 29915 Lejos
# Annotation in words_annotations/annotations/31894.TextGrid does not exists
# 31894 Encima
# Annotation in words_annotations/annotations/36181.TextGrid does not exists
# 36181 Debajo
# Annotation in words_annotations/annotations/33224.TextGrid does not exists
# 33224 Izquierda
# Annotation in words_annotations/annotations/30864.TextGrid does not exists
# 30864 Derecha
# Annotation in words_annotations/annotations/32740.TextGrid does not exists
# 32740 Adelante
# Annotation in words_annotations/annotations/30173.TextGrid does not exists
# 30173 Atrás
# Annotation in words_annotations/annotations/36905.TextGrid does not exists
# 36905 Grande
# Annotation in words_annotations/annotations/30868.TextGrid does not exists
# 30868 Mediano
# Annotation in words_annotations/annotations/35290.TextGrid does not exists
# 35290 Pequeño
# Annotation in words_annotations/annotations/34370.TextGrid does not exists
# 34370 Largo
# Annotation in words_annotations/annotations/31436.TextGrid does not exists
# 31436 Corto
# Annotation in words_annotations/annotations/32936.TextGrid does not exists
# 32936 Dentro
# Annotation in words_annotations/annotations/34742.TextGrid does not exists
# 34742 Fuera
# Annotation in words_annotations/annotations/36912.TextGrid does not exists
# 36912 Bonito
# Annotation in words_annotations/annotations/35039.TextGrid does not exists
# 35039 Feo
# TRANSCRIPTION: Rápido
# Annotation Rápido not found
# 28028 Rápido
# TRANSCRIPTION: Lento
# 28867 Lento
# Annotation in words_annotations/annotations/34747.TextGrid does not exists
# 34747 Blando
# Annotation in words_annotations/annotations/32754.TextGrid does not exists
# 32754 Duro
# Annotation in words_annotations/annotations/36129.TextGrid does not exists
# 36129 Sentarse
# Annotation in words_annotations/annotations/31739.TextGrid does not exists
# 31739 Pararse
# Annotation in words_annotations/annotations/31740.TextGrid does not exists
# 31740 Mayor
# TRANSCRIPTION: Menor
# 28873 Menor
# Annotation in words_annotations/annotations/32410.TextGrid does not exists
# 32410 Igual
# Annotation in words_annotations/annotations/32587.TextGrid does not exists
# 32587 Cumpleaños
# Annotation in words_annotations/annotations/33641.TextGrid does not exists
# 33641 Navidad
# Annotation in words_annotations/annotations/31654.TextGrid does not exists
# 31654 Año nuevo
# TRANSCRIPTION: Día del Niño
# Annotation Día del Niño not found
# 27488 Día del Niño
# TRANSCRIPTION: Halloween
# 28235 Halloween
# Annotation in words_annotations/annotations/34672.TextGrid does not exists
# 34672 Día de la Mujer
# Annotation in words_annotations/annotations/33165.TextGrid does not exists
# 33165 Día de la Madre
# Annotation in words_annotations/annotations/32331.TextGrid does not exists
# 32331 Día del Padre
# Annotation in words_annotations/annotations/30766.TextGrid does not exists
# 30766 Día del Idioma
# TRANSCRIPTION: Día del Profesor
# Annotation Día del Profesor not found
# 29476 Día del Profesor
# TRANSCRIPTION: Color
# 29103 Color
# Annotation in words_annotations/annotations/29975.TextGrid does not exists
# 29975 Amarillo
# Annotation in words_annotations/annotations/33315.TextGrid does not exists
# 33315 Azul
# Annotation in words_annotations/annotations/31612.TextGrid does not exists
# 31612 Rojo
# TRANSCRIPTION: Verde
# 28335 Verde
# TRANSCRIPTION: Naranja
# 29429 Naranja
# TRANSCRIPTION: Violeta
# 29816 Violeta
# Annotation in words_annotations/annotations/34631.TextGrid does not exists
# 34631 Café
# TRANSCRIPTION: Negro
# 27612 Negro
# TRANSCRIPTION: Blanco
# 27881 Blanco
# Annotation in words_annotations/annotations/32552.TextGrid does not exists
# 32552 Gris
# Annotation in words_annotations/annotations/31331.TextGrid does not exists
# 31331 Rosado
# Annotation in words_annotations/annotations/33572.TextGrid does not exists
# 33572 Caminar
# Annotation in words_annotations/annotations/35678.TextGrid does not exists
# 35678 Correr
# Annotation in words_annotations/annotations/36453.TextGrid does not exists
# 36453 Nadar
# TRANSCRIPTION: Jugar
# 28796 Jugar
# Annotation in words_annotations/annotations/34171.TextGrid does not exists
# 34171 Comer
# Annotation in words_annotations/annotations/35682.TextGrid does not exists
# 35682 Dormir
# Annotation in words_annotations/annotations/30465.TextGrid does not exists
# 30465 Limpiar
# Annotation in words_annotations/annotations/35139.TextGrid does not exists
# 35139 Bañar
# Annotation in words_annotations/annotations/32482.TextGrid does not exists
# 32482 Hora
# TRANSCRIPTION: Minuto
# 28196 Minuto
# Annotation in words_annotations/annotations/33526.TextGrid does not exists
# 33526 Segundo
# TRANSCRIPTION: Día
# Annotation Día not found
# 28970 Día
# Annotation in words_annotations/annotations/36844.TextGrid does not exists
# 36844 Día festivo
# Annotation in words_annotations/annotations/34830.TextGrid does not exists
# 34830 Semana
# Annotation in words_annotations/annotations/30427.TextGrid does not exists
# 30427 Mes
# Annotation in words_annotations/annotations/35185.TextGrid does not exists
# 35185 Año
# Annotation in words_annotations/annotations/35080.TextGrid does not exists
# 35080 Enero
# Annotation in words_annotations/annotations/36650.TextGrid does not exists
# 36650 Febrero
# Annotation in words_annotations/annotations/33534.TextGrid does not exists
# 33534 Marzo
# Annotation in words_annotations/annotations/34464.TextGrid does not exists
# 34464 Abril
# Annotation in words_annotations/annotations/32143.TextGrid does not exists
# 32143 Mayo
# TRANSCRIPTION: Junio
# 28276 Junio
# Annotation in words_annotations/annotations/34839.TextGrid does not exists
# 34839 Julio
# Annotation in words_annotations/annotations/31535.TextGrid does not exists
# 31535 Agosto
# TRANSCRIPTION: Septiembre
# 29672 Septiembre
# Annotation in words_annotations/annotations/31537.TextGrid does not exists
# 31537 Octubre
# Annotation in words_annotations/annotations/36486.TextGrid does not exists
# 36486 Noviembre
# Annotation in words_annotations/annotations/33543.TextGrid does not exists
# 33543 Diciembre
# TRANSCRIPTION: Lunes
# 28290 Lunes
# Annotation in words_annotations/annotations/34474.TextGrid does not exists
# 34474 Martes
# TRANSCRIPTION: Miércoles
# Annotation Miércoles not found
# 28545 Miércoles
# Annotation in words_annotations/annotations/36588.TextGrid does not exists
# 36588 Jueves
# TRANSCRIPTION: Viernes
# 28769 Viernes
# Annotation in words_annotations/annotations/32507.TextGrid does not exists
# 32507 Sábado
# Annotation in words_annotations/annotations/32673.TextGrid does not exists
# 32673 Domingo
# Annotation in words_annotations/annotations/31141.TextGrid does not exists
# 31141 Mañana
# TRANSCRIPTION: Tarde
# 28316 Tarde
# Annotation in words_annotations/annotations/31143.TextGrid does not exists
# 31143 Noche
# Annotation in words_annotations/annotations/36871.TextGrid does not exists
# 36871 Ayer
# Annotation in words_annotations/annotations/36410.TextGrid does not exists
# 36410 Hoy
# TRANSCRIPTION: Buenos días
# Annotation Buenos días not found
# 29626 Buenos días
# Annotation in words_annotations/annotations/36034.TextGrid does not exists
# 36034 Buenas tardes
# Annotation in words_annotations/annotations/36257.TextGrid does not exists
# 36257 Buenas noches
# Annotation in words_annotations/annotations/31493.TextGrid does not exists
# 31493 Hola
# Annotation in words_annotations/annotations/35749.TextGrid does not exists
# 35749 ¿Cómo estás?
# Annotation in words_annotations/annotations/36260.TextGrid does not exists
# 36260 Adiós
# Annotation in words_annotations/annotations/33971.TextGrid does not exists
# 33971 Bienvenido
# Annotation in words_annotations/annotations/30398.TextGrid does not exists
# 30398 Gracias
# Annotation in words_annotations/annotations/33773.TextGrid does not exists
# 33773 Camisa
# TRANSCRIPTION: Pantalón
# Annotation Pantalón not found
# 28465 Pantalón
# Annotation in words_annotations/annotations/33775.TextGrid does not exists
# 33775 Blusa
# Annotation in words_annotations/annotations/31464.TextGrid does not exists
# 31464 Falda
# Annotation in words_annotations/annotations/35960.TextGrid does not exists
# 35960 Saco
# Annotation in words_annotations/annotations/35322.TextGrid does not exists
# 35322 Gorro
# Annotation in words_annotations/annotations/33470.TextGrid does not exists
# 33470 Sombrero
# TRANSCRIPTION: Zapato
# 28893 Zapato
# Annotation in words_annotations/annotations/33781.TextGrid does not exists
# 33781 Medias
# Annotation in words_annotations/annotations/33782.TextGrid does not exists
# 33782 Guantes
# TRANSCRIPTION: Pantaloneta
# 28474 Pantaloneta
# Annotation in words_annotations/annotations/35618.TextGrid does not exists
# 35618 Computador
# Annotation in words_annotations/annotations/32473.TextGrid does not exists
# 32473 Celular
# Annotation in words_annotations/annotations/36316.TextGrid does not exists
# 36316 Teclado
# Annotation in words_annotations/annotations/31106.TextGrid does not exists
# 31106 Ratón
# Annotation in words_annotations/annotations/31807.TextGrid does not exists
# 31807 Pantalla
# Annotation in words_annotations/annotations/36000.TextGrid does not exists
# 36000 Facebook
# TRANSCRIPTION: WhatsApp
# 28183 WhatsApp
# Annotation in words_annotations/annotations/31110.TextGrid does not exists
# 31110 Televisión
# Annotation in words_annotations/annotations/32480.TextGrid does not exists
# 32480 Radio
# Annotation in words_annotations/annotations/32481.TextGrid does not exists
# 32481 Internet
# Annotation in words_annotations/annotations/31284.TextGrid does not exists
# 31284 Perro
# Annotation in words_annotations/annotations/33369.TextGrid does not exists
# 33369 Gato
# TRANSCRIPTION: Gallina
# 29130 Gallina
# Annotation in words_annotations/annotations/33820.TextGrid does not exists
# 33820 Conejo
# Annotation in words_annotations/annotations/32820.TextGrid does not exists
# 32820 Sapo
# TRANSCRIPTION: Pato
# 29275 Pato
# Annotation in words_annotations/annotations/33283.TextGrid does not exists
# 33283 Ballena
# TRANSCRIPTION: Cerdo
# 27843 Cerdo
# Annotation in words_annotations/annotations/32980.TextGrid does not exists
# 32980 Pollito
# TRANSCRIPTION: León
# Annotation León not found
# 28285 León
# TRANSCRIPTION: Tigre
# 27414 Tigre
# Annotation in words_annotations/annotations/33828.TextGrid does not exists
# 33828 Delfín
# Annotation in words_annotations/annotations/32030.TextGrid does not exists
# 32030 Tiburón
# Annotation in words_annotations/annotations/34231.TextGrid does not exists
# 34231 Oso
# TRANSCRIPTION: Caballo
# 27418 Caballo
# Annotation in words_annotations/annotations/34603.TextGrid does not exists
# 34603 Tortuga
# Annotation in words_annotations/annotations/32034.TextGrid does not exists
# 32034 Serpiente
# Annotation in words_annotations/annotations/33085.TextGrid does not exists
# 33085 Vaca
# TRANSCRIPTION: Pez
# Annotation Pez not found
# 29226 Pez
# TRANSCRIPTION: Ratón
# Annotation Ratón not found
# 27424 Ratón
# Annotation in words_annotations/annotations/33921.TextGrid does not exists
# 33921 Mono
# TRANSCRIPTION: Mico
# 28309 Mico
# Annotation in words_annotations/annotations/30106.TextGrid does not exists
# 30106 Cocodrilo
# TRANSCRIPTION: Oveja
# 28313 Oveja
# Annotation in words_annotations/annotations/33733.TextGrid does not exists
# 33733 Elefante
# TRANSCRIPTION: Pájaro
# Annotation Pájaro not found
# 29413 Pájaro
# Annotation in words_annotations/annotations/34947.TextGrid does not exists
# 34947 Mariposa
# TRANSCRIPTION: Jirafa
# 27593 Jirafa
# TRANSCRIPTION: Caracol
# 28157 Caracol
# TRANSCRIPTION: Moto
# 28999 Moto
# Annotation in words_annotations/annotations/36412.TextGrid does not exists
# 36412 Carro
# Annotation in words_annotations/annotations/34152.TextGrid does not exists
# 34152 Bicicleta
# Annotation in words_annotations/annotations/32517.TextGrid does not exists
# 32517 Bus
# Annotation in words_annotations/annotations/35665.TextGrid does not exists
# 35665 Tren
# Annotation in words_annotations/annotations/34491.TextGrid does not exists
# 34491 Avión
# Annotation in words_annotations/annotations/36603.TextGrid does not exists
# 36603 Ambulancia
# TRANSCRIPTION: Aretes
# 27357 Aretes
# TRANSCRIPTION: Reloj
# 27370 Reloj
# Annotation in words_annotations/annotations/34186.TextGrid does not exists
# 34186 Cadena
# TRANSCRIPTION: Gafas
# 29724 Gafas
# Annotation in words_annotations/annotations/34894.TextGrid does not exists
# 34894 Anillo
# Annotation in words_annotations/annotations/33851.TextGrid does not exists
# 33851 Correa
# TRANSCRIPTION: Pulsera
# 27518 Pulsera
