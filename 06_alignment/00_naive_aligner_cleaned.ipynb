# %%
import copy
import os
import re

from matplotlib import pyplot as plt
import textgrids
from scipy.io import wavfile
from silence_aligner import extract_segments_from_file
import IPython.display
from jiwer import wer

# %%
AUDIOS_FOLDER = "cropped_audios"
TRANSCRIPTION_FOLDER = "cropped_annotations"
TEXTS_FOLDER = "texts"
OUTPUT_ALIGN_FOLDER = "naive_align"

# %%
def sent_tokenize(text):
    return [x for x in re.split("\.|,|;|:|\n|!|¿|¡|\?|-|—|\(|\)|«|»", text) if x.replace(" ", "")]


def align_single(base_file_name):
    frequency_from_signal, signal = wavfile.read(
        os.path.join(
            AUDIOS_FOLDER,
            f"{base_file_name}.wav"
        )
    )
    silences, frequency  = extract_segments_from_file(
        os.path.join(
            AUDIOS_FOLDER,
            f"{base_file_name}.wav"
        )
    )

    segments = list()
    last_start = 0
    for start, stop in silences:
        segments.append((last_start, start))
        last_start = stop

    segments.append((last_start,signal.shape[-1]))
    with open(
        os.path.join(
            TEXTS_FOLDER,
            f"{base_file_name.replace('cropped_', '')}.txt"
        )
    ) as file:
        text = " ".join(file.readlines())

    tokens = sent_tokenize(text)
    tokens = tokens[1:]
    words_count = len(text.split(" "))
    transcription = textgrids.TextGrid(
        os.path.join(
            TRANSCRIPTION_FOLDER,
            f"{base_file_name}.TextGrid"
        )
    )

    intervals = transcription[base_file_name.replace("cropped_", "")]
    alignment = list()
    for index, current_segment in enumerate(segments):
        try:
            alignment.append(
                {
                    "text": tokens[index].replace("\"", "'"),
                    "xmin" : current_segment[0]/frequency,
                    "xmax" : current_segment[1]/frequency
                }
            )
        except IndexError:
            print("Breaking on index", index)
            break


    tg = textgrids.TextGrid()
    tg.xmin = 0
    tg.xmax = silences[-1][1] / frequency
    tier = textgrids.Tier()
    tg[base_file_name] = tier

    for align in alignment:
        tier.append(
            textgrids.Interval(
                align["text"],
                align["xmin"],
                align["xmax"]
            )
        )

    tg.write(
        os.path.join(
            OUTPUT_ALIGN_FOLDER,
            f"{base_file_name}.TextGrid"
        )
    )

    wer_list = list()

    current_annotation_index = 0
    current_interval_index = 0
    while current_interval_index < len(intervals):
        try:
            interval = intervals[current_interval_index]
            t_text = interval.text
            t_min = interval.xmin
            t_max = interval.xmax

            a_text = alignment[current_annotation_index]["text"]
            a_min = alignment[current_annotation_index]["xmin"]
            a_xmax = alignment[current_annotation_index]["xmax"]

            if a_xmax < t_max + 1:

                wer_list.append((tokens[int(t_text)-1], a_text))
            else:

                interval_to_append = [t_text]

                while not a_xmax < t_max + 1:

                    current_interval_index += 1
                    interval = intervals[current_interval_index]
                    t_text = interval.text
                    t_min = interval.xmin
                    t_max = interval.xmax
                    interval_to_append.append(t_text)
                value_to_append = list()
                for i in interval_to_append:
                    try:
                        value_to_append.append(tokens[int(i)-1])
                    except ValueError:
                        print("Error decoding", i)
                wer_list.append(("".join(value_to_append), a_text))


            current_interval_index += 1
            current_annotation_index += 1
        except (IndexError, ValueError):
            print("Exiting on index current_interval_index", current_interval_index, "current_annotation_index", current_annotation_index)
            break

    wer_values = list()
    for x in wer_list:
        true_value = x[0].split()
        inferred_value = x[1].split()
        local_wer = wer(true_value, inferred_value)
        percentaje = len(true_value)/ words_count
        wer_values.append(local_wer * percentaje)
    total_wer = sum(wer_values)
    return total_wer * 100

# %%
results = list()
output_text = ""
for file_name in os.listdir(TRANSCRIPTION_FOLDER):
    print("================")
    print(file_name)
    try:
        base_file_name = file_name.replace(".TextGrid", "")
        local_wer = align_single(
                base_file_name
            )
        results.append(
            local_wer
        )
        output_text += f"{base_file_name}, {local_wer}\n"

    except (FileNotFoundError, ValueError, IndexError) as e:
        print("File not found on", file_name)
        output_text += f"{base_file_name}, {e} \n"
# Out:
# ================
# cropped_F_13_1.TextGrid
# Desired threshold, 0.05
# 2807376715.761885
# Exiting on index current_interval_index 16 current_annotation_index 8
# ================
# cropped_M_45_1.TextGrid
# Desired threshold, 0.05
# 1693037607.5033379
# Breaking on index 344
# Exiting on index current_interval_index 344 current_annotation_index 344
# ================
# cropped_M_74_1.TextGrid
# Desired threshold, 0.05
# 2125183467.5488214
# Breaking on index 10
# Exiting on index current_interval_index 10 current_annotation_index 10
# ================
# cropped_F_73_1.TextGrid
# Desired threshold, 0.05
# 3262914028.40407
# Breaking on index 12
# Exiting on index current_interval_index 12 current_annotation_index 12
# ================
# cropped_M_27_1.TextGrid
# Desired threshold, 0.05
# 11036553227.861982
# Breaking on index 154
# Exiting on index current_interval_index 154 current_annotation_index 152
# ================
# cropped_F_60_1.TextGrid
# Desired threshold, 0.05
# 4381507435.437266
# Error decoding
# ================
# cropped_F_10_1.TextGrid
# Desired threshold, 0.05
# 269450236.9541746
# File not found on cropped_F_10_1.TextGrid
# ================
# cropped_M_15_1.TextGrid
# Desired threshold, 0.05
# 4278862679.0722523
# Breaking on index 19
# Exiting on index current_interval_index 19 current_annotation_index 17
# ================
# cropped_M_71_1.TextGrid
# Desired threshold, 0.05
# 0.01088053934242552
# File not found on cropped_M_71_1.TextGrid
# ================
# cropped_M_70_1.TextGrid
# Desired threshold, 0.05
# 1620344246.9001057
# Breaking on index 9
# Exiting on index current_interval_index 9 current_annotation_index 9
# ================
# cropped_F_74_1.TextGrid
# Desired threshold, 0.05
# 2260028588.27425
# Breaking on index 16
# Exiting on index current_interval_index 16 current_annotation_index 16
# ================
# cropped_M_61_1.TextGrid
# Desired threshold, 0.05
# 1926477248.433329
# Breaking on index 19
# Exiting on index current_interval_index 19 current_annotation_index 19
# ================
# cropped_F_40_1.TextGrid
# Desired threshold, 0.05
# 9738576635.586637
# Exiting on index current_interval_index 369 current_annotation_index 169
# ================
# cropped_M_63_1.TextGrid
# Desired threshold, 0.05
# 1464485534.7844021
# Exiting on index current_interval_index 198 current_annotation_index 117
# ================
# cropped_F_29_1.TextGrid
# Desired threshold, 0.05
# 1146343467.1599004
# Exiting on index current_interval_index 161 current_annotation_index 147
# ================
# cropped_M_04_1.TextGrid
# Desired threshold, 0.05
# 2143631389.7199247
# Breaking on index 15
# Exiting on index current_interval_index 15 current_annotation_index 14
# ================
# cropped_M_42_1.TextGrid
# Desired threshold, 0.05
# 282587056.1031066
# Exiting on index current_interval_index 15 current_annotation_index 11
# ================
# cropped_F_30_1.TextGrid
# Desired threshold, 0.05
# 5116316169.457007
# Breaking on index 396
# Exiting on index current_interval_index 395 current_annotation_index 395
# ================
# cropped_F_69_1.TextGrid
# Desired threshold, 0.05
# 5664178716.835491
# Exiting on index current_interval_index 20 current_annotation_index 17
# ================
# cropped_M_38_1.TextGrid
# Desired threshold, 0.05
# 937581638.8489491
# Breaking on index 84
# Exiting on index current_interval_index 84 current_annotation_index 84
# ================
# cropped_M_30_1.TextGrid
# Desired threshold, 0.05
# 2030214226.9151628
# Exiting on index current_interval_index 16 current_annotation_index 12
# ================
# cropped_F_64_1.TextGrid
# Desired threshold, 0.05
# 346712317.60320115
# Exiting on index current_interval_index 15 current_annotation_index 10
# ================
# cropped_F_34_1.TextGrid
# Desired threshold, 0.05
# 2216104465.16678
# Exiting on index current_interval_index 120 current_annotation_index 21
# ================
# cropped_M_66_1.TextGrid
# Desired threshold, 0.05
# 2877318357.757764
# Breaking on index 72
# Exiting on index current_interval_index 66 current_annotation_index 66
# ================
# cropped_F_38_1.TextGrid
# Desired threshold, 0.05
# 1915418401.8660557
# Exiting on index current_interval_index 226 current_annotation_index 191
# ================
# cropped_M_73_1.TextGrid
# Desired threshold, 0.05
# 1209390911.9698863
# Breaking on index 6
# Exiting on index current_interval_index 6 current_annotation_index 6
# ================
# cropped_M_06_1.TextGrid
# Desired threshold, 0.05
# 3242250538.2129173
# Breaking on index 15
# Exiting on index current_interval_index 15 current_annotation_index 15
# ================
# cropped_F_56_1.TextGrid
# Desired threshold, 0.05
# 2579080222.640761
# Breaking on index 15
# Exiting on index current_interval_index 15 current_annotation_index 15
# ================
# cropped_M_11_1.TextGrid
# Desired threshold, 0.05
# 0.6838903985533173
# File not found on cropped_M_11_1.TextGrid
# ================
# cropped_F_63_1.TextGrid
# Desired threshold, 0.05
# 4983479384.606131
# Breaking on index 132
# Exiting on index current_interval_index 133 current_annotation_index 132
# ================
# cropped_M_01_1.TextGrid
# Desired threshold, 0.05
# 2340015168.22082
# Exiting on index current_interval_index 73 current_annotation_index 41
# ================
# cropped_F_50_1.TextGrid
# Desired threshold, 0.05
# 4042865982.682248
# Breaking on index 46
# Exiting on index current_interval_index 43 current_annotation_index 43
# ================
# cropped_F_71_1.TextGrid
# Desired threshold, 0.05
# 15685938270.088413
# Error decoding
# ================
# cropped_M_13_1.TextGrid
# Desired threshold, 0.05
# 984423892.2858887
# Breaking on index 19
# Exiting on index current_interval_index 18 current_annotation_index 18
# ================
# cropped_F_61_1.TextGrid
# Desired threshold, 0.05
# 90437720.04233474
# Error decoding
# ================
# cropped_F_55_1.TextGrid
# Desired threshold, 0.05
# 3283568582.826064
# Breaking on index 15
# Exiting on index current_interval_index 16 current_annotation_index 15
# ================
# cropped_M_05_1.TextGrid
# Desired threshold, 0.05
# 45.89378613798339
# File not found on cropped_M_05_1.TextGrid
# ================
# cropped_F_52_1.TextGrid
# Desired threshold, 0.05
# 253965511.66145498
# Breaking on index 12
# Exiting on index current_interval_index 12 current_annotation_index 10
# ================
# cropped_F_48_1.TextGrid
# Desired threshold, 0.05
# 0.0
# File not found on cropped_F_48_1.TextGrid
# ================
# cropped_M_28_1.TextGrid
# Desired threshold, 0.05
# 2175358332.363099
# Exiting on index current_interval_index 44 current_annotation_index 30
# ================
# cropped_F_19_1.TextGrid
# Desired threshold, 0.05
# 5067526615.703743
# Breaking on index 249
# Exiting on index current_interval_index 249 current_annotation_index 249
# ================
# cropped_M_55_1.TextGrid
# Desired threshold, 0.05
# 2553836923.9303274
# Exiting on index current_interval_index 13 current_annotation_index 10
# ================
# cropped_M_68_1.TextGrid
# Desired threshold, 0.05
# 1485701618.1407895
# Breaking on index 23
# Exiting on index current_interval_index 23 current_annotation_index 22
# ================
# cropped_F_59_1.TextGrid
# Desired threshold, 0.05
# 69625.1247842798
# File not found on cropped_F_59_1.TextGrid
# ================
# cropped_M_41_1.TextGrid
# Desired threshold, 0.05
# 51849748.332319915
# Exiting on index current_interval_index 20 current_annotation_index 11
# ================
# cropped_F_27_1.TextGrid
# Desired threshold, 0.05
# 1226732668.0901453
# Exiting on index current_interval_index 32 current_annotation_index 25
# ================
# cropped_F_33_1.TextGrid
# Desired threshold, 0.05
# 2282779998.565538
# Breaking on index 279
# Exiting on index current_interval_index 275 current_annotation_index 275
# ================
# cropped_F_44_1.TextGrid
# Desired threshold, 0.05
# 10469422339.653046
# Exiting on index current_interval_index 316 current_annotation_index 185
# ================
# cropped_F_08_1.TextGrid
# Desired threshold, 0.05
# 3619967448.9380054
# Error decoding
# Exiting on index current_interval_index 20 current_annotation_index 15
# ================
# cropped_F_66_1.TextGrid
# Desired threshold, 0.05
# 1100811061.2859848
# Exiting on index current_interval_index 17 current_annotation_index 15
# ================
# cropped_M_72_1.TextGrid
# Desired threshold, 0.05
# 1.8321683347636957
# File not found on cropped_M_72_1.TextGrid
# ================
# cropped_F_47_1.TextGrid
# Desired threshold, 0.05
# 64.29669145911332
# File not found on cropped_F_47_1.TextGrid
# ================
# cropped_M_67_1.TextGrid
# Desired threshold, 0.05
# 2.1531615942132682
# File not found on cropped_M_67_1.TextGrid
# ================
# cropped_M_47_1.TextGrid
# Desired threshold, 0.05
# 2774194592.5850854
# Error decoding
# ================
# cropped_F_54_1.TextGrid
# Desired threshold, 0.05
# 1306719933.3806849
# Breaking on index 8
# Exiting on index current_interval_index 8 current_annotation_index 7
# ================
# cropped_F_70_1.TextGrid
# Desired threshold, 0.05
# 2340.5989856870037
# File not found on cropped_F_70_1.TextGrid
# ================
# cropped_M_19_1.TextGrid
# Desired threshold, 0.05
# 4070710347.4928026
# Breaking on index 362
# Exiting on index current_interval_index 361 current_annotation_index 361
# ================
# cropped_M_21_1.TextGrid
# Desired threshold, 0.05
# 10582091578.320267
# Breaking on index 21
# Exiting on index current_interval_index 20 current_annotation_index 19

# %%
total_wer = sum(results)/len(results)
output_text += f"TOTAL_RESULTS, {total_wer}\n"

# %%
with open("naive_results.txt", "w+") as results_file:
    results_file.write(output_text)
