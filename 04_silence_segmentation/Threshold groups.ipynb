# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
thresholds = np.loadtxt("thresholds.txt")
thresholds
# Out:
# array([0.01      , 0.01000002, 0.01      , 0.01000008, 0.01000003,
#        0.01000728, 0.01      , 0.01      , 0.01000008, 0.01000002,
#        0.01      , 0.01000151, 0.01000135, 0.01038993, 0.01000044,
#        0.01000193, 0.01000004, 0.01016349, 0.0100073 , 0.01004234,
#        0.01      , 0.01000001, 0.01000003, 0.01000001, 0.01      ,
#        0.01012897, 0.01000033, 0.01      , 0.01      , 0.01103316,
#        0.01000306, 0.01000001, 0.01000182, 0.01      , 0.01000053,
#        0.01000075, 0.01000131, 0.01036712, 0.01000001, 0.01      ,
#        0.01000177, 0.01000028, 0.01000001, 0.01      , 0.01000532,
#        0.01      , 0.01      , 0.01      , 0.01008335, 0.01      ,
#        0.01000034, 0.01      , 0.01003538, 0.01      ])

# %%
plt.plot(thresholds)

# %%
sorted_threshold = np.sort(thresholds)
plt.plot(sorted_threshold)

# %%
plt.scatter(np.arange(sorted_threshold.shape[-1]), sorted_threshold)
